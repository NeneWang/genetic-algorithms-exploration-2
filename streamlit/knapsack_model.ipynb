# %%
import streamlit as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pprint
from deap import base, creator, tools, algorithms
import pandas as pd
from modules.knapsack_tools import ITEMS_KNAPSACK, MAX_CAPACITY, apply_tournament, KnapsackProblem, run_knapsack_tournament

# %%
populations = [x for x in range(50, 1000, 50)]
generations = [x for x in range(50, 500, 50)]
crossover_probabilities = [x/10 for x in range(1, 10)]
mutation_probabilities = [x/10 for x in range(1, 10)]

selection_methods = [
    tools.selTournament, 
    tools.selRoulette, 
    tools.selBest
]
k = [x for x in range(1, 10)]
experiments_arr = []


for i in range(10):
    # select rnadom between options.
    population = np.random.choice(populations)
    generation = np.random.choice(generations)
    crossover_probability = np.random.choice(crossover_probabilities)
    mutation_probability = np.random.choice(mutation_probabilities)
    selection_method = np.random.choice(selection_methods)
    k_value = np.random.choice(k)
    
    
    toolbox = base.Toolbox()
    
    if selection_method == tools.selTournament:
        toolbox.register("select", selection_method, tournsize=k_value)    
    if selection_method == tools.selBest:
        toolbox.register("select", tools.selBest)
    if selection_method == tools.selRoulette:
        toolbox.register("select", tools.selRoulette, k=k_value)
    
    resuls = run_knapsack_tournament(toolbox, population, crossover_probability, mutation_probability, generation)
    logbook = resuls['logbook']
    max_found_at = logbook.select('max_found_at')[-1]
    end_mean_fitness_population = logbook.select('avg')[-1]
    end_max_fitness = logbook.select('max')[-1]
    experiments = {
        'max_found_at: ': max_found_at, 
        'end_mean_fitness_population: ': end_mean_fitness_population, 
        'end_max_fitness: ': end_max_fitness,
        "population": population,
        "generation": generation,
        "crossover_probability": crossover_probability,
        "mutation_probability": mutation_probability,
        "selection_method": selection_method,
        "k_value": k_value
        
    }
    pprint.pprint(experiments)
    experiments_arr.append(experiments)
df_experiments = pd.DataFrame(experiments_arr)
df_experiments.to_csv('reports/knapsack_experiments_random.csv')
df_experiments.head(40)
# Out:
# Initalized with capacity:  400
# c:\Python310\lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# c:\Python310\lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# {'crossover_probability': 0.8,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1000.0,
#  'generation': 400,
#  'k_value': 2,
#  'max_found_at: ': 28,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selRoulette at 0x00000216B3744DC0>}
# Initalized with capacity:  400
# {'crossover_probability': 0.4,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 952.4876923076923,
#  'generation': 400,
#  'k_value': 4,
#  'max_found_at: ': 9,
#  'mutation_probability': 0.9,
#  'population': 650,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.9,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1012.7914285714286,
#  'generation': 350,
#  'k_value': 4,
#  'max_found_at: ': 7,
#  'mutation_probability': 0.3,
#  'population': 350,
#  'selection_method': <function selBest at 0x00000216B3744C10>}
# Initalized with capacity:  400
# {'crossover_probability': 0.8,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 990.2266666666667,
#  'generation': 200,
#  'k_value': 4,
#  'max_found_at: ': 7,
#  'mutation_probability': 0.5,
#  'population': 450,
#  'selection_method': <function selRoulette at 0x00000216B3744DC0>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1023.66,
#  'generation': 200,
#  'k_value': 1,
#  'max_found_at: ': 10,
#  'mutation_probability': 0.1,
#  'population': 400,
#  'selection_method': <function selBest at 0x00000216B3744C10>}
# Initalized with capacity:  400
# {'crossover_probability': 0.7,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1011.0,
#  'generation': 300,
#  'k_value': 3,
#  'max_found_at: ': 113,
#  'mutation_probability': 0.3,
#  'population': 100,
#  'selection_method': <function selRoulette at 0x00000216B3744DC0>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 990.0036363636364,
#  'generation': 150,
#  'k_value': 5,
#  'max_found_at: ': 14,
#  'mutation_probability': 0.6,
#  'population': 550,
#  'selection_method': <function selRoulette at 0x00000216B3744DC0>}
# Initalized with capacity:  400
# {'crossover_probability': 0.6,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1012.045,
#  'generation': 400,
#  'k_value': 1,
#  'max_found_at: ': 20,
#  'mutation_probability': 0.4,
#  'population': 200,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.6,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1014.9353846153846,
#  'generation': 100,
#  'k_value': 3,
#  'max_found_at: ': 7,
#  'mutation_probability': 0.2,
#  'population': 650,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.6,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1024.2941176470588,
#  'generation': 300,
#  'k_value': 2,
#  'max_found_at: ': 6,
#  'mutation_probability': 0.1,
#  'population': 850,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
#    max_found_at:   end_mean_fitness_population:   end_max_fitness:   \
# 0              28                    1000.000000             1030.0
# 1               9                     952.487692             1030.0
# 2               7                    1012.791429             1030.0
# 3               7                     990.226667             1030.0
# 4              10                    1023.660000             1030.0
# 5             113                    1011.000000             1030.0
# 6              14                     990.003636             1030.0
# 7              20                    1012.045000             1030.0
# 8               7                    1014.935385             1030.0
# 9               6                    1024.294118             1030.0
#
#    population  generation  crossover_probability  mutation_probability  \
# 0          50         400                    0.8                   0.5
# 1         650         400                    0.4                   0.9
# 2         350         350                    0.9                   0.3
# 3         450         200                    0.8                   0.5
# 4         400         200                    0.1                   0.1
# 5         100         300                    0.7                   0.3
# 6         550         150                    0.2                   0.6
# 7         200         400                    0.6                   0.4
# 8         650         100                    0.6                   0.2
# 9         850         300                    0.6                   0.1
#
#                                  selection_method  k_value
# 0    <function selRoulette at 0x00000216B3744DC0>        2
# 1  <function selTournament at 0x00000216B3744D30>        4
# 2        <function selBest at 0x00000216B3744C10>        4
# 3    <function selRoulette at 0x00000216B3744DC0>        4
# 4        <function selBest at 0x00000216B3744C10>        1
# 5    <function selRoulette at 0x00000216B3744DC0>        3
# 6    <function selRoulette at 0x00000216B3744DC0>        5
# 7  <function selTournament at 0x00000216B3744D30>        1
# 8  <function selTournament at 0x00000216B3744D30>        3
# 9  <function selTournament at 0x00000216B3744D30>        2

# %%
populations = [x for x in range(50, 1000, 250)]
generations = [x for x in range(50, 400, 50)]
crossover_probabilities = [x/10 for x in range(1, 10)]
mutation_probabilities = [x/10 for x in range(1, 10)]

selection_methods = [
    tools.selTournament, 
    tools.selRoulette, 
    tools.selBest
]
k = [x for x in range(1, 10)]
experiments_arr = []


for selection_method in selection_methods:
    for population in populations:
        for generation in generations:
            for crossover_probability in crossover_probabilities:
                for mutation_probability in mutation_probabilities:
                    for k_value in k:
                        toolbox = base.Toolbox()
                        selection_strategy_name = ""
                        if selection_method == tools.selTournament:
                            toolbox.register("select", selection_method, tournsize=k_value)    
                            strategy_name = "Tournament"
                        if selection_method == tools.selBest:
                            toolbox.register("select", tools.selBest)
                            strategy_name = "Best"
                        if selection_method == tools.selRoulette:
                            toolbox.register("select", tools.selRoulette, k=k_value)
                            strategy_name = "Roulette"
    
                        resuls = run_knapsack_tournament(toolbox, population, crossover_probability, mutation_probability, generation)
                        logbook = resuls['logbook']
                        max_found_at = logbook.select('max_found_at')[-1]
                        end_mean_fitness_population = logbook.select('avg')[-1]
                        end_max_fitness = logbook.select('max')[-1]
                        
                        
                        experiments = {
                            'max_found_at: ': max_found_at, 
                            'end_mean_fitness_population: ': end_mean_fitness_population, 
                            'end_max_fitness: ': end_max_fitness,
                            "population": population,
                            "generation": generation,
                            "crossover_probability": crossover_probability,
                            "mutation_probability": mutation_probability,
                            "selection_method": selection_method,
                            "selection_strategy_name": strategy_name,
                            "k_value": k_value
                            
                        }
                        pprint.pprint(experiments)
                        experiments_arr.append(experiments)
df_experiments = pd.DataFrame(experiments_arr)
df_experiments.to_csv('experiments.csv')
df_experiments.head(40)
# Out:
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 955.0,
#  'end_mean_fitness_population: ': 922.3,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 50,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 990.4,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 30,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 966.9,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 30,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 965.0,
#  'end_mean_fitness_population: ': 960.7,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 12,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 991.64,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 22,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 1000.0,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 45,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 964.64,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 22,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# c:\Python310\lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# c:\Python310\lib\site-packages\deap\creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 940.0,
#  'end_mean_fitness_population: ': 939.04,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 45,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 940.0,
#  'end_mean_fitness_population: ': 929.9,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 20,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 955.0,
#  'end_mean_fitness_population: ': 943.14,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 980.84,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 11,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 981.02,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 16,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 915.0,
#  'end_mean_fitness_population: ': 907.44,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 3,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1024.3,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 930.0,
#  'end_mean_fitness_population: ': 911.88,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 46,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1008.36,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 46,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1017.1,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 34,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 915.0,
#  'end_mean_fitness_population: ': 909.6,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 3,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 992.5,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 15,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 975.56,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 17,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1008.98,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 22,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 985.12,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 35,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 990.0,
#  'end_mean_fitness_population: ': 963.76,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 45,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 959.3,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 8,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 985.0,
#  'end_mean_fitness_population: ': 956.72,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 30,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 915.0,
#  'end_mean_fitness_population: ': 893.5,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 4,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 989.0,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 23,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 957.24,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 50,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 965.0,
#  'end_mean_fitness_population: ': 930.68,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 1,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 979.64,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 50,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 976.28,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 33,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 989.64,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 13,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1004.38,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 37,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 972.84,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 34,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 981.24,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 46,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 972.78,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 41,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 957.86,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 15,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 985.0,
#  'end_mean_fitness_population: ': 935.56,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 33,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 948.9,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 41,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 969.08,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 46,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 952.82,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 5,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 974.74,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 29,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 967.9,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 47,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 967.0,
#  'end_mean_fitness_population: ': 929.1,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 8,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 970.3,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 8,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 968.12,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 45,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 973.88,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 19,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 933.48,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 6,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 989.38,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 29,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 962.68,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 20,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 983.34,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 32,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 963.1,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 20,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 937.84,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 40,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 975.88,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 990.12,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 17,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 976.58,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 12,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 962.84,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 11,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 954.88,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 42,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 945.6,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 38,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 951.78,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 11,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 985.94,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 16,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 980.18,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 33,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 997.0,
#  'end_mean_fitness_population: ': 931.88,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 46,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 969.84,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 17,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 949.68,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 13,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 978.68,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 35,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 946.6,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 39,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 960.54,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 9,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 975.26,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 969.9,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 11,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 990.0,
#  'end_mean_fitness_population: ': 927.38,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 48,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 958.5,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 21,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 952.52,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 31,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 928.02,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 36,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 953.1,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 15,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 924.92,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 38,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 913.02,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 40,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 970.44,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 34,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 967.74,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 17,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 947.58,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 40,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 957.46,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 26,
#  'mutation_probability': 0.9,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 987.0,
#  'end_mean_fitness_population: ': 985.66,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 41,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 969.0,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 41,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 967.0,
#  'end_mean_fitness_population: ': 960.86,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 7,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 915.0,
#  'end_mean_fitness_population: ': 902.42,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 5,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 925.0,
#  'end_mean_fitness_population: ': 922.3,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 19,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 990.0,
#  'end_mean_fitness_population: ': 978.54,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 49,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 975.0,
#  'end_mean_fitness_population: ': 967.0,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 39,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 915.0,
#  'end_mean_fitness_population: ': 912.44,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 2,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 990.0,
#  'end_mean_fitness_population: ': 983.78,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 40,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 996.64,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 42,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 983.22,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 37,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 979.24,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 23,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 960.0,
#  'end_mean_fitness_population: ': 942.48,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 10,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 950.0,
#  'end_mean_fitness_population: ': 941.04,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 43,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 991.6,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 38,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 982.0,
#  'end_mean_fitness_population: ': 955.46,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 41,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 915.0,
#  'end_mean_fitness_population: ': 903.58,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 5,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 952.0,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 41,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 978.1,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 11,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 989.3,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 26,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 959.34,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 9,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1009.44,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 29,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1019.86,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 13,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1006.12,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 25,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 980.84,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 24,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 965.0,
#  'end_mean_fitness_population: ': 946.6,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 6,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 990.0,
#  'end_mean_fitness_population: ': 968.92,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 23,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 985.7,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 48,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 962.82,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 19,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1010.0,
#  'end_mean_fitness_population: ': 968.32,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 50,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1011.36,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 42,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 997.94,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 35,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 978.2,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 44,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 975.04,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 22,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 978.3,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 13,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 994.56,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 7,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 967.0,
#  'end_mean_fitness_population: ': 947.14,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 31,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 972.02,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 46,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 940.46,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 42,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 975.8,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 11,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 965.32,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 14,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 987.4,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 49,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 941.14,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 35,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 963.84,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 48,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 940.6,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 12,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 976.56,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 26,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 938.82,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 49,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 990.0,
#  'end_mean_fitness_population: ': 938.78,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 8,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 987.1,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 38,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 966.68,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 45,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 964.38,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 38,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 987.04,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 32,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 996.32,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 16,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 980.42,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 19,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 970.84,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 30,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 951.06,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 962.5,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 39,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 982.68,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 16,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 963.94,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 4,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 948.68,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 49,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 959.38,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 25,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 960.02,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 49,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1010.0,
#  'end_mean_fitness_population: ': 963.26,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.7,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 968.22,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 15,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 962.42,
#  'generation': 50,
#  'k_value': 2,
#  'max_found_at: ': 14,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 954.64,
#  'generation': 50,
#  'k_value': 3,
#  'max_found_at: ': 36,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 943.08,
#  'generation': 50,
#  'k_value': 4,
#  'max_found_at: ': 48,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 949.52,
#  'generation': 50,
#  'k_value': 5,
#  'max_found_at: ': 25,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 970.0,
#  'end_mean_fitness_population: ': 930.64,
#  'generation': 50,
#  'k_value': 6,
#  'max_found_at: ': 26,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 939.22,
#  'generation': 50,
#  'k_value': 7,
#  'max_found_at: ': 7,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 945.32,
#  'generation': 50,
#  'k_value': 8,
#  'max_found_at: ': 26,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1002.0,
#  'end_mean_fitness_population: ': 937.5,
#  'generation': 50,
#  'k_value': 9,
#  'max_found_at: ': 50,
#  'mutation_probability': 0.8,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.2,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 980.9,
#  'generation': 50,
#  'k_value': 1,
#  'max_found_at: ': 13,
#  'mutation_probability': 0.9,
#  'population': 50,
# ...
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1016.1,
#  'generation': 300,
#  'k_value': 9,
#  'max_found_at: ': 234,
#  'mutation_probability': 0.1,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1014.3,
#  'generation': 300,
#  'k_value': 1,
#  'max_found_at: ': 196,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1012.94,
#  'generation': 300,
#  'k_value': 2,
#  'max_found_at: ': 156,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1012.08,
#  'generation': 300,
#  'k_value': 3,
#  'max_found_at: ': 106,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1010.5,
#  'generation': 300,
#  'k_value': 4,
#  'max_found_at: ': 205,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1013.06,
#  'generation': 300,
#  'k_value': 5,
#  'max_found_at: ': 260,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 967.0,
#  'end_mean_fitness_population: ': 948.76,
#  'generation': 300,
#  'k_value': 6,
#  'max_found_at: ': 85,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1023.04,
#  'generation': 300,
#  'k_value': 7,
#  'max_found_at: ': 171,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 957.0,
#  'end_mean_fitness_population: ': 951.62,
#  'generation': 300,
#  'k_value': 8,
#  'max_found_at: ': 13,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1022.22,
#  'generation': 300,
#  'k_value': 9,
#  'max_found_at: ': 58,
#  'mutation_probability': 0.2,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1014.66,
#  'generation': 300,
#  'k_value': 1,
#  'max_found_at: ': 76,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1010.22,
#  'generation': 300,
#  'k_value': 2,
#  'max_found_at: ': 111,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1013.94,
#  'generation': 300,
#  'k_value': 3,
#  'max_found_at: ': 19,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 988.7,
#  'generation': 300,
#  'k_value': 4,
#  'max_found_at: ': 263,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 995.98,
#  'generation': 300,
#  'k_value': 5,
#  'max_found_at: ': 85,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1005.0,
#  'end_mean_fitness_population: ': 979.26,
#  'generation': 300,
#  'k_value': 6,
#  'max_found_at: ': 275,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1021.9,
#  'generation': 300,
#  'k_value': 7,
#  'max_found_at: ': 55,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 998.74,
#  'generation': 300,
#  'k_value': 8,
#  'max_found_at: ': 174,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 973.8,
#  'generation': 300,
#  'k_value': 9,
#  'max_found_at: ': 246,
#  'mutation_probability': 0.3,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1003.9,
#  'generation': 300,
#  'k_value': 1,
#  'max_found_at: ': 160,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1001.64,
#  'generation': 300,
#  'k_value': 2,
#  'max_found_at: ': 181,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1000.0,
#  'generation': 300,
#  'k_value': 3,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 999.56,
#  'generation': 300,
#  'k_value': 4,
#  'max_found_at: ': 27,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1021.76,
#  'generation': 300,
#  'k_value': 5,
#  'max_found_at: ': 213,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1000.1,
#  'generation': 300,
#  'k_value': 6,
#  'max_found_at: ': 125,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 999.52,
#  'generation': 300,
#  'k_value': 7,
#  'max_found_at: ': 203,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 987.88,
#  'generation': 300,
#  'k_value': 8,
#  'max_found_at: ': 112,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 996.58,
#  'generation': 300,
#  'k_value': 9,
#  'max_found_at: ': 69,
#  'mutation_probability': 0.4,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 987.86,
#  'generation': 300,
#  'k_value': 1,
#  'max_found_at: ': 22,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 985.16,
#  'generation': 300,
#  'k_value': 2,
#  'max_found_at: ': 107,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1000.4,
#  'generation': 300,
#  'k_value': 3,
#  'max_found_at: ': 176,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 979.16,
#  'generation': 300,
#  'k_value': 4,
#  'max_found_at: ': 10,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1000.0,
#  'end_mean_fitness_population: ': 969.62,
#  'generation': 300,
#  'k_value': 5,
#  'max_found_at: ': 173,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 994.92,
#  'generation': 300,
#  'k_value': 6,
#  'max_found_at: ': 154,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1001.94,
#  'generation': 300,
#  'k_value': 7,
#  'max_found_at: ': 54,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 985.68,
#  'generation': 300,
#  'k_value': 8,
#  'max_found_at: ': 116,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 1007.0,
#  'generation': 300,
#  'k_value': 9,
#  'max_found_at: ': 120,
#  'mutation_probability': 0.5,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 997.1,
#  'generation': 300,
#  'k_value': 1,
#  'max_found_at: ': 71,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 990.52,
#  'generation': 300,
#  'k_value': 2,
#  'max_found_at: ': 90,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# {'crossover_probability': 0.1,
#  'end_max_fitness: ': 1030.0,
#  'end_mean_fitness_population: ': 983.32,
#  'generation': 300,
#  'k_value': 3,
#  'max_found_at: ': 44,
#  'mutation_probability': 0.6,
#  'population': 50,
#  'selection_method': <function selTournament at 0x00000216B3744D30>}
# Initalized with capacity:  400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 29
#      26 if selection_method == tools.selRoulette:
#      27     toolbox.register("select", tools.selRoulette, k=k_value)
# ---> 29 resuls = run_knapsack_tournament(toolbox, population, crossover_probability, mutation_probability, generation)
#      30 logbook = resuls['logbook']
#      31 max_found_at = logbook.select('max_found_at')[-1]
#
# File e:\wangn\Documents\GitHub\genetic-algorithms-exploration-2\streamlit\modules\knapsack_tools.py:106, in run_knapsack_tournament(toolbox, population_size, crossover_prob, mutation_prob, max_generations, items, max_capacity, apply_selection)
#     103 hof = tools.HallOfFame(HALL_OF_FAME_SIZE)
#     104 hof.clear()
# --> 106 population, logbook = algorithms.eaSimple(population, toolbox, cxpb=P_CROSSOVER, mutpb=P_MUTATION,
#     107                                             ngen=MAX_GENERATIONS, stats=stats, halloffame=hof, verbose=False)
#     109 # For some reason this is not working
#     110 return {
#     111     "best_solution": knapsack.best_solution,
#     112     "best_value": knapsack.best_value,
#    (...)
#     115     "knapsack": knapsack
#     116 }
#
# File c:\Python310\lib\site-packages\deap\algorithms.py:171, in eaSimple(population, toolbox, cxpb, mutpb, ngen, stats, halloffame, verbose)
#     168 offspring = toolbox.select(population, len(population))
#     170 # Vary the pool of individuals
# --> 171 offspring = varAnd(offspring, toolbox, cxpb, mutpb)
#     173 # Evaluate the individuals with an invalid fitness
#     174 invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#
# File c:\Python310\lib\site-packages\deap\algorithms.py:68, in varAnd(population, toolbox, cxpb, mutpb)
#      33 def varAnd(population, toolbox, cxpb, mutpb):
#      34     r"""Part of an evolutionary algorithm applying only the variation part
#      35     (crossover **and** mutation). The modified individuals have their
#      36     fitness invalidated. The individuals are cloned so returned population is
#    (...)
#      66     :math:`[0, 1]`.
#      67     """
# ---> 68     offspring = [toolbox.clone(ind) for ind in population]
#      70     # Apply crossover and mutation on the offspring
#      71     for i in range(1, len(offspring), 2):
#
# File c:\Python310\lib\site-packages\deap\algorithms.py:68, in <listcomp>(.0)
#      33 def varAnd(population, toolbox, cxpb, mutpb):
#      34     r"""Part of an evolutionary algorithm applying only the variation part
#      35     (crossover **and** mutation). The modified individuals have their
#      36     fitness invalidated. The individuals are cloned so returned population is
#    (...)
#      66     :math:`[0, 1]`.
#      67     """
# ---> 68     offspring = [toolbox.clone(ind) for ind in population]
#      70     # Apply crossover and mutation on the offspring
#      71     for i in range(1, len(offspring), 2):
#
# File c:\Python310\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File c:\Python310\lib\copy.py:289, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     287     for item in listiter:
#     288         item = deepcopy(item, memo)
# --> 289         y.append(item)
#     290 else:
#     291     for item in listiter:
#
# KeyboardInterrupt:
